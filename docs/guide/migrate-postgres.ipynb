# %% [markdown]
# # Confirm a migration dialogue

# %%
from nbproject import header, publish
import lndb_setup

header()

# %%
# !lndb init --storage migtest_postgres --schema bionty --db postgresql://batman:robin@35.222.187.204:5432/movies

# %% [markdown]
# Now go back to the latest version of the schema.

# %% [markdown]
# Let us trigger a migration to the most recent version, by translating the following command-line call
# ```
# lndb load migtest
# ```
# into this API call:

# %%
assert lndb_setup.load("movies") in ["migrate-unnecessary", "migrate-success"]

# %% [markdown]
# Clean up.
